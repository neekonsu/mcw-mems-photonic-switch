# %% [markdown]
# # Etch Hole
#
# Single square etch hole used as a sub-component in shuttle beams, moving comb drives, and other released MEMS structures.

# %%
import sys
sys.path.insert(0, "../../libraries")

from mcw_custom_optical_mems_pdk import PDK
PDK.activate()

from etch_hole import make_etch_hole

# %%
hole = make_etch_hole(size=5.0)
hole.plot()
