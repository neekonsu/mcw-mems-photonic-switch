# %% [markdown]
# # Focusing Grating Coupler
#
# Curved/focusing grating coupler with elliptical partial-etch teeth on SOI. Each grating arc simultaneously diffracts and focuses light into a 440 nm strip waveguide — no taper needed.

# %%
import sys
sys.path.insert(0, "../../libraries")

from mcw_custom_optical_mems_pdk import PDK
PDK.activate()

from grating_coupler import make_grating_coupler

# %%
c = make_grating_coupler()
c.plot()

# %%
c.write_gds("grating_coupler.gds")
print("Wrote grating_coupler.gds")
# Out:
# Wrote grating_coupler.gds
