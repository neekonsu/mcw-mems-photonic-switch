# %% [markdown]
# # Trace to Pad
#
# A 2 µm wide POLY_MEMS trace, 20 µm long, terminated with a metal bond pad.

# %%
import sys
sys.path.insert(0, "../../libraries")

from mcw_custom_optical_mems_pdk import PDK
PDK.activate()

from trace_to_pad import make_trace_to_pad

# %%
c = make_trace_to_pad()
c.plot()

# %%
c.write_gds("trace_to_pad.gds")
print("Wrote trace_to_pad.gds")
