# %% [markdown]
# # Anchor Components
#
# Fixed anchor frames with internal grid ribs, multi-layer MEMS anchors
# (POLY_TOP + POLY_MEMS + SI_FULL), and metal pads.
#
# Adapted from Sirui's reference design (`draw_fixedanchor_*`, `draw_mems_anchor*`, `draw_mems_pad`).

# %%
import sys
sys.path.insert(0, "../../libraries")

from mcw_custom_optical_mems_pdk import PDK
PDK.activate()

from anchor import (
    make_anchor_frame,
    make_anchor_frame_large,
    make_anchor_frame_cut,
    make_mems_anchor,
    make_mems_anchor_cut,
    make_mems_pad,
)

# %% [markdown]
# ## Anchor Frame (ceiling-rounded holes)

# %%
af = make_anchor_frame(30, 110, 10, 5)
af.plot()

# %% [markdown]
# ## Anchor Frame with Corner Cut

# %%
afc = make_anchor_frame_cut(50, 110, 30, 70, 10, 5)
afc.plot()

# %% [markdown]
# ## 3-Layer MEMS Anchor

# %%
ma = make_mems_anchor(30, 20, 2, 0.8, 0.3, 0.3)
ma.plot()

# %% [markdown]
# ## 3-Layer MEMS Anchor with Corner Cut

# %%
mac = make_mems_anchor_cut(50, 20, 20, 10, 2, 0.8, 0.3, 0.3)
mac.plot()

# %% [markdown]
# ## 4-Layer MEMS Pad (with Metal)

# %%
mp = make_mems_pad(30, 30, 2, 0.8, 0.3, 0.3, 1.0)
mp.plot()
