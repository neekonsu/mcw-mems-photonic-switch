# %% [markdown]
# # Folded Spring
#
# 4-beam folded spring pair that connects the proof mass to the anchor.
# Purely structural (POLY_MEMS layer only).
#
# Adapted from Sirui's reference design (`draw_spring_pair`).

# %%
import sys
sys.path.insert(0, "../../libraries")

from mcw_custom_optical_mems_pdk import PDK
PDK.activate()

from folded_spring import make_spring_pair

# %%
sp = make_spring_pair(
    spring_length=30,
    spring_width=0.5,
    spring_gap=5,
    anchor_gap_length=7,
    pad_length=8,
    pad_width=0.8,
)
sp.plot()

# %% [markdown]
# ## Longer Springs (for multi-comb variant)

# %%
sp_long = make_spring_pair(
    spring_length=45,
    spring_width=0.5,
    spring_gap=5,
    anchor_gap_length=7,
    pad_length=8,
    pad_width=0.8,
)
sp_long.plot()
